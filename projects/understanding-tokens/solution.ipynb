# %% [markdown]
# Tokenizing with code

# %%
import tiktoken

# %%
encoding = tiktoken.encoding_for_model("gpt-4.1-mini")
tokens=encoding.encode("Hello, world!")
print(tokens)
# Out:
# [13225, 11, 2375, 0]

# %%
for token_id in tokens:
    print(f"{token_id}: {encoding.decode([token_id])}")
# Out:
# 13225: Hello
# 11: ,
# 2375:  world
# 0: !

# %%
encoding.decode([2375])
# Out:
# ' world'
